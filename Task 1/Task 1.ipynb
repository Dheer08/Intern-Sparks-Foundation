# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# %%
dataset = pd.read_csv(r"student_scores.csv")
dataset.head(5)
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
plt.scatter(dataset["Hours"],dataset["Scores"])
plt.xlabel("Hours")
plt.ylabel("Scores")
plt.title("Hours Vs Scores")
# Out:
# Text(0.5, 1.0, 'Hours Vs Scores')

# %%
X = dataset.iloc[:,:-1]
Y = dataset.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
line = model.coef_ * X + model.intercept_

plt.plot(X,line)
plt.scatter(X,Y)
plt.xlabel("Hours")
plt.ylabel("Scores")
# Out:
# Text(0, 0.5, 'Scores')

# %%
y_pred = model.predict(x_test)
df = pd.DataFrame({"Actual": y_test, "Predicted Values ": y_pred})
df
# Out:
#     Actual  Predicted Values
# 5       20          16.884145
# 2       27          33.732261
# 19      69          75.357018
# 16      30          26.794801
# 11      62          60.491033

# %%
MAE = mean_absolute_error(y_test,y_pred)
MAE
# Out:
# 4.183859899002982

# %%
val = model.predict(np.array([[9.25]]))
print(f"predicted score for a studying 9 and 1/2 years {val}")
# Out:
# predicted score for a studying 9 and 1/2 years [93.69173249]
